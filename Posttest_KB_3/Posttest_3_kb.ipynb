# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %% [markdown]
# # GRAFIK BATANG

# %%
plt.figure(figsize=(5,18))
x = list(df["Year"])
y = list(df["Car_Name"])

plt.xlabel("customer")
plt.ylabel("penjualan")
plt.title("Grafik Batang")
plt.bar(x,y,color="red")
plt.show()

# %% [markdown]
# # Grafik Box Plot

# %%
plt.figure(figsize=(5,18))
plt.title('Grafik Boxplot')
sns.boxplot(data=df,x="Year",y="Car_Name")
plt.show()

# %% [markdown]
# # GRAFIK GARIS DAN FLOT

# %%
plt.figure(figsize=(25,10))
x = list(df["Year"])
y = list(df["Present_Price"])
plt.title("Grafik Garis")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # GRAFIK PIE

# %%
data_pie = df["Year"].value_counts()
data_pie = df["Year"].value_counts().rename_axis("Year")
data_pie = df["Year"].value_counts().rename_axis("Year").reset_index(name="NO")
data_pie.head(10)
# Out:
#    Year  NO
# 0  2015  61
# 1  2016  50
# 2  2014  38
# 3  2017  35
# 4  2013  33
# 5  2012  23
# 6  2011  19
# 7  2010  15
# 8  2008   7
# 9  2009   6

# %%
plt.figure(figsize=(10,20))
plt.title("Grafik Pie Merek Mobil Pada Tahun Yang Berbeda")
plt.pie(data_pie["NO"], labels=data_pie["Year"], startangle=90, autopct="%.2f%%")
plt.show()

# %% [markdown]
# # Grafik Scatter Plot

# %%
plt.figure(figsize=(10,10))
plt.xlabel("Harga")
plt.ylabel("Tahun")
plt.scatter(x=df["Selling_Price"], y=df["Year"])
plt.show()

# %% [markdown]
# # Kesimpulan Dari Visulasisasi Data
# ## Visualasis data adalah pemetaan atau menampilkan data-data yang ada dalam bentuk grafik
# #### Dari data yang telah divisualasi didapatkan Penjualan Mobil Bermerek Jazz yang paling laku dan Merek mobil Ritz terbilang tidak laku
# #### Harga yang paling tinggi terjadi di tahun 2010 yaitu 35
